# %%
from datashader.utils import lnglat_to_meters as webm
from functools import partial
from datashader.utils import export_image
from datashader.colors import colormap_select , Greys9
from IPython.core.display import HTML , display
import pandas as pd
import datashader as ds
import datashader.transfer_functions as tf
from datetime import datetime

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# 1         40.731152                  N            663
# 2         40.710087                  N           2124
# 3         40.706718                  N            429
# 4         40.782520                  N            435

# %%
df.drop(['id' , 'vendor_id' , 'passenger_count' , 'store_and_fwd_flag','trip_duration'] , axis = 1)
# Out:
#              pickup_datetime     dropoff_datetime  pickup_longitude  \
# 0        2016-03-14 17:24:55  2016-03-14 17:32:30        -73.982155
# 1        2016-06-12 00:43:35  2016-06-12 00:54:38        -73.980415
# 2        2016-01-19 11:35:24  2016-01-19 12:10:48        -73.979027
# 3        2016-04-06 19:32:31  2016-04-06 19:39:40        -74.010040
# 4        2016-03-26 13:30:55  2016-03-26 13:38:10        -73.973053
# ...                      ...                  ...               ...
# 1458639  2016-04-08 13:31:04  2016-04-08 13:44:02        -73.982201
# 1458640  2016-01-10 07:35:15  2016-01-10 07:46:10        -74.000946
# 1458641  2016-04-22 06:57:41  2016-04-22 07:10:25        -73.959129
# 1458642  2016-01-05 15:56:26  2016-01-05 16:02:39        -73.982079
# 1458643  2016-04-05 14:44:25  2016-04-05 14:47:43        -73.979538
#
#          pickup_latitude  dropoff_longitude  dropoff_latitude
# 0              40.767937         -73.964630         40.765602
# 1              40.738564         -73.999481         40.731152
# 2              40.763939         -74.005333         40.710087
# 3              40.719971         -74.012268         40.706718
# 4              40.793209         -73.972923         40.782520
# ...                  ...                ...               ...
# 1458639        40.745522         -73.994911         40.740170
# 1458640        40.747379         -73.970184         40.796547
# 1458641        40.768799         -74.004433         40.707371
# 1458642        40.749062         -73.974632         40.757107
# 1458643        40.781750         -73.972809         40.790585
#
# [1458644 rows x 6 columns]

# %%
pickup_hour = []
dropoff_hour = []
for i in range(1458644):
    datetime_str = df['pickup_datetime'][i]
    datetime_object = datetime.strptime(datetime_str, '%Y-%m-%d %H:%M:%S')
    pickup_hour.append(datetime_object.hour)
    datetime_str = df['dropoff_datetime'][i]
    datetime_object = datetime.strptime(datetime_str, '%Y-%m-%d %H:%M:%S')
    dropoff_hour.append(datetime_object.hour)
df['pickup_hour'] = pickup_hour
df['dropoff_hour'] = dropoff_hour

# %%
num = 0

# %%
i = 12
df_hour = df.loc[df['pickup_hour'] == i].copy()
s = "Hour_" + str(i)

# %%
df_hour.drop(columns = ['id' , 'vendor_id' , 'passenger_count' , 'store_and_fwd_flag','trip_duration'])
df_hour
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 11       id1299289          2  2016-05-15 11:16:11  2016-05-15 11:34:59
# 55       id3827863          2  2016-04-19 11:29:08  2016-04-19 12:27:56
# 57       id1079955          1  2016-04-22 11:28:00  2016-04-22 12:11:27
# 66       id1182327          2  2016-02-29 11:22:35  2016-02-29 11:35:43
# ...            ...        ...                  ...                  ...
# 1458457  id0960839          2  2016-04-17 11:22:43  2016-04-17 11:37:41
# 1458468  id0818159          2  2016-02-10 11:57:17  2016-02-10 12:14:32
# 1458568  id2231538          2  2016-04-29 11:30:44  2016-04-29 11:40:44
# 1458570  id1608086          1  2016-06-06 11:57:49  2016-06-06 12:04:43
# 1458632  id0469946          2  2016-03-06 11:04:48  2016-03-06 11:17:45
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 2                      1        -73.979027        40.763939
# 11                     4        -73.991531        40.749439
# 55                     3        -73.792892        40.657879
# 57                     1        -73.994850        40.718781
# 66                     1        -73.948303        40.774437
# ...                  ...               ...              ...
# 1458457                1        -73.998093        40.723560
# 1458468                5        -73.982674        40.772152
# 1458568                6        -73.979431        40.755470
# 1458570                1        -73.944931        40.778645
# 1458632                2        -74.015572        40.710892
#
#          dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 2               -74.005333         40.710087                  N
# 11              -73.956543         40.770630                  N
# 55              -73.809189         40.690182                  N
# 57              -73.983414         40.758850                  N
# 66              -73.963707         40.755486                  N
# ...                    ...               ...                ...
# 1458457         -73.976562         40.683609                  N
# 1458468         -73.982635         40.763317                  N
# 1458568         -73.991173         40.749668                  N
# 1458570         -73.924332         40.807053                  N
# 1458632         -73.996620         40.743633                  N
#
#          trip_duration  pickup_hour  dropoff_hour
# 2                 2124           11            12
# 11                1128           11            11
# 55                3528           11            12
# 57                2607           11            12
# 66                 788           11            11
# ...                ...          ...           ...
# 1458457            898           11            11
# 1458468           1035           11            12
# 1458568            600           11            11
# 1458570            414           11            12
# 1458632            777           11            11
#
# [68476 rows x 13 columns]

# %%
df_hour.loc[:,'easting'] , df_hour.loc[:,'northing'] = webm(df['pickup_longitude'] , df['pickup_latitude'])
df_hour.head()
# Out:
#            id  vendor_id      pickup_datetime     dropoff_datetime  \
# 2   id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 11  id1299289          2  2016-05-15 11:16:11  2016-05-15 11:34:59
# 55  id3827863          2  2016-04-19 11:29:08  2016-04-19 12:27:56
# 57  id1079955          1  2016-04-22 11:28:00  2016-04-22 12:11:27
# 66  id1182327          2  2016-02-29 11:22:35  2016-02-29 11:35:43
#
#     passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 2                 1        -73.979027        40.763939         -74.005333
# 11                4        -73.991531        40.749439         -73.956543
# 55                3        -73.792892        40.657879         -73.809189
# 57                1        -73.994850        40.718781         -73.983414
# 66                1        -73.948303        40.774437         -73.963707
#
#     dropoff_latitude store_and_fwd_flag  trip_duration  pickup_hour  \
# 2          40.710087                  N           2124           11
# 11         40.770630                  N           1128           11
# 55         40.690182                  N           3528           11
# 57         40.758850                  N           2607           11
# 66         40.755486                  N            788           11
#
#     dropoff_hour       easting      northing
# 2             12 -8.235308e+06  4.977585e+06
# 11            11 -8.236700e+06  4.975454e+06
# 55            12 -8.214587e+06  4.962009e+06
# 57            12 -8.237069e+06  4.970950e+06
# 66            11 -8.231887e+06  4.979128e+06

# %%
y_range_min = df_hour['pickup_latitude'].quantile(0.01)
y_range_max = df_hour['pickup_latitude'].quantile(0.99)
x_range_min = df_hour['pickup_longitude'].quantile(0.01)
x_range_max = df_hour['pickup_longitude'].quantile(0.99)
sw = webm(x_range_min,y_range_min)
ne = webm(x_range_max,y_range_max)
SF = zip(sw,ne)
plot_width = int(500)
plot_height = int(500)
background = "black"
export = partial(export_image,background=background,export_path = "Analysis")
cm = partial(colormap_select , reverse = (background != "black"))

display(HTML("<style>.container {width : 100% !important;}</style>"))
cvs = ds.Canvas(plot_width,plot_height,*SF)
agg = cvs.points(df_hour,'easting','northing')
# Out:
# <style>.container {width : 100% !important;}</style>

# %%
export(tf.shade(agg , cmap = cm(Greys9,0.2) ) , s)
# Out:
# <xarray.Image (northing: 500, easting: 500)>
# array([[4278190080, 4278190080, 4280624421, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * easting   (easting) float64 -8.239e+06 -8.239e+06 ... -8.214e+06 -8.214e+06
#   * northing  (northing) float64 4.96e+06 4.96e+06 ... 4.983e+06 4.984e+06

# %%
from colorcet import fire
s = s + "_fire"
export(tf.shade(agg,cmap = cm(fire,0.2) , how = 'log') , s)
# Out:
# <xarray.Image (northing: 500, easting: 500)>
# array([[4278190080, 4278190080, 4278190440, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * easting   (easting) float64 -8.239e+06 -8.239e+06 ... -8.214e+06 -8.214e+06
#   * northing  (northing) float64 4.96e+06 4.96e+06 ... 4.983e+06 4.984e+06

# %%
num = num + df_hour.shape[0]
del(df_hour)
